# %%
import astropy.units as u
from astropy.io import fits
from spectral_cube import SpectralCube
from spectral_cube import BooleanArrayMask
import matplotlib.pyplot as plt
from bokeh.plotting import output_notebook, figure, show


output_notebook()
# %matplotlib widget
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
cube1= SpectralCube.read('../data/FixedAstrometryDATACUBE_FINAL.fits',hdu=1)
# Out:
# WARNING: UnitsWarning: '10**(-20)*erg/s/cm**2/Angstrom' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
halpha = cube1.spectral_slab(6550*u.angstrom, 6560*u.angstrom).median(axis=0)
halpha.quicklook()
# Out:
# INFO: Auto-setting vmin to -6.291e+03 [aplpy.core]
# INFO: Auto-setting vmax to  7.065e+04 [aplpy.core]

# %%
todos = cube1.spectral_slab(6400*u.angstrom, 6500*u.angstrom).mean(axis=0)
resta = halpha - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=True)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f6956fc0488>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# INFO: Auto-setting vmin to -6.588e+03 [aplpy.core]
# INFO: Auto-setting vmax to  1.065e+03 [aplpy.core]
# INFO: Auto-setting vmin to -4.240e+03 [aplpy.core]
# INFO: Auto-setting vmax to  8.350e+02 [aplpy.core]

# %%
#resta.write('restaHalpha.fits')

# %% [markdown]
#  # Plot spectra from region

# %%
ds9_str = 'fk5; circle(17:40:41.0354,-53:40:16.824,0.4")' 
subcube = cube1.subcube_from_ds9region(ds9_str)  
spectrum = subcube.mean(axis=(1, 2)) 

# create a new plot
p = figure(plot_width=1000, plot_height=500, title="U")

# add some renderers
p.line(cube1.spectral_axis,spectrum)
show(p)
# Out:
# /home/mmarcano/anaconda3/lib/python3.7/site-packages/spectral_cube/masks.py:632: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return LazyMask(self._function, data=self._data[view],
# /home/mmarcano/anaconda3/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:1222: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return self._new_cube_with(data=self._data[view],
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f6956fc0488>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
#   <div class="bk-root" id="71d3ed2b-5b28-4c85-bce4-462e864ca228"></div>

# %% [markdown]
# # With short you can see U18 cearly

# %%
halpha = cube1.spectral_slab(6560*u.angstrom, 6570*u.angstrom).median(axis=0)




todos = cube1.spectral_slab(6500*u.angstrom, 6600*u.angstrom).mean(axis=0)
resta = halpha - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=False)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')
# Out:
# WARNING: PossiblySlowWarning: This function (<function BaseSpectralCube.mean at 0x7f6956fc0488>) requires loading the entire cube into memory and may therefore be slow. [spectral_cube.utils]
# /home/mmarcano/anaconda3/lib/python3.7/site-packages/spectral_cube/spectral_cube.py:400: RuntimeWarning: Mean of empty slice
#   **kwargs)
# INFO: Auto-setting vmin to -5.395e+03 [aplpy.core]
# INFO: Auto-setting vmax to  5.593e+02 [aplpy.core]
# INFO: Auto-setting vmin to -4.662e+03 [aplpy.core]
# INFO: Auto-setting vmax to  4.862e+02 [aplpy.core]

# %% [markdown]
# # Helium try

# %%
he5875 = cube1.spectral_slab(7060*u.angstrom, 7070*u.angstrom).median(axis=0)




todos = cube1.spectral_slab(7000*u.angstrom, 7100*u.angstrom).median(axis=0)
resta = he5875 - todos
#resta.write('restaHalpha2.fits')
resta.quicklook()
lmc =resta.FITSFigure
#lmc.set_tick_labels_format(xformat='hh:mm:ss',yformat='dd:mm:ss')
lmc.show_grayscale(invert=False)
#lmc.show_colorscale(cmap='grayscale')
lmc.add_grid()
#lmc.tick_labels.set_xformat('ddd.dddd')
#lmc.tick_labels.set_yformat('ddd.dddd')

#lmc.show_grayscale(stretch='arcsinh',invert=True)
#lmc.show_grayscale(stretch='arcsinh', vmin=1, vmax=10,invert=True)
#lmc.show_grid()
#lmc.set_grid_alpha(0.2)
#lmc.set_grid_color('black')
#lmc.set_axis_labels_size('18')
#lmc.set_tick_labels_size('16')
#lmc.set_tick_color('black')

resta.write('restaHeI7065.fits')
# Out:
# INFO: Auto-setting vmin to -1.700e+02 [aplpy.core]
# INFO: Auto-setting vmax to  5.977e+01 [aplpy.core]
# INFO: Auto-setting vmin to -1.888e+02 [aplpy.core]
# INFO: Auto-setting vmax to  6.519e+01 [aplpy.core]
